# %%
# pip install seaborn 
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yield_apples = [0.89, 0.91, 0.92, 0.93, 0.94, 0.95]

# %%
plt.plot(years,yield_apples)

# %%
years = [2017, 2018, 2019, 2020, 2021, 2022]

# %%
apples = [0.89, 0.91, 0.92, 0.93, 0.94, 0.95]
tangerines = [0.78, 0.83, 0.92, 0.99, 0.98, 0.76]

# %%
plt.plot(years, apples)
plt.plot(years, tangerines)

plt.xlabel('Year')
plt.ylabel('Yield(tons per hectare)');

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples)
plt.plot(years, tangerines)

plt.xlabel('Year')
plt.ylabel('Yield(tons per hectare)');

plt.title("")
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import pandas as pd

# %%
crops_yields = dict(tahun=years, apel=apples, jeruk=tangerines)
panen= pd.DataFrame(crops_yields)

# %%
panen
# Out:
#    tahun  apel  jeruk
# 0   2017  0.89   0.78
# 1   2018  0.91   0.83
# 2   2019  0.92   0.92
# 3   2020  0.93   0.99
# 4   2021  0.94   0.98
# 5   2022  0.95   0.76

# %%
ax = sns.lineplot

# %%
plt.bar(years, tangerines)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop yields in Kanto")
# Out:
# Text(0.5, 1.0, 'Crop yields in Kanto')

# %%
tips_df = sns.load_dataset("tips")
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day', y='total_bill', data=tips_df)

# %%
sns.barplot(y='day', x='total_bill', hue='sex', data=tips_df)

# %%
iris_df = sns.load_dataset("iris")
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
setosa_df =  iris_df[iris_df.species== 'setosa']
versicolor =  iris_df[iris_df.species== 'versicolor']
virginica =  iris_df[iris_df.species== 'virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha = 0.4) #alpha untuk ketebalan histogramnya
plt.hist(versicolor.sepal_width, alpha = 0.4)
# Out:
# (array([ 1.,  2.,  6.,  4.,  3., 11.,  7., 11.,  3.,  2.]),
#  array([2.  , 2.14, 2.28, 2.42, 2.56, 2.7 , 2.84, 2.98, 3.12, 3.26, 3.4 ]),
#  <a list of 10 Patch objects>)

# %%
plt.title

plt.hist

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("Number of passengers (1000s)")
sns.heatmap(flights_df)

# %%
sns.heatmap(flights_df)
